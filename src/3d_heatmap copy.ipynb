# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib import cm
from matplotlib import colors
from datetime import datetime

# %%
corona_df = pd.read_csv("../data/corona_data.csv", index_col="pref_name")
latlong_df = pd.read_csv("../data/latlong_data.csv", index_col="pref_name")

# # コロナ感染データ
# corona_data = """
# pref_name,2020-1-16,2020-1-17,2020-1-18
# Hokkaido,3,4,300
# Aomori,231,333,56
# """

# # 県ごとの緯度経度データ
# latlong_data = """
# pref_name,lat,lon
# Hokkaido,43.064359,141.347449
# Aomori,40.824294,140.740054
# """
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 corona_df = pd.read_csv("../data/corona_data.csv", index_col="pref_name")
#       2 latlong_df = pd.read_csv("../data/latlong_data.csv", index_col="pref_name")
#       4 # # コロナ感染データ
#       5 # corona_data = """
#       6 # pref_name,2020-1-16,2020-1-17,2020-1-18
#    (...)
#      15 # Aomori,40.824294,140.740054
#      16 # """
#
# ...

# %%
# 三次元ヒートマップの描画
fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")

# 県ごとに繰り返し
for pref_name in confirmed_cases_daily_df.index:
    # 緯度経度取得
    lat = lat_lon_df.loc[pref_name, "lat"]
    lon = lat_lon_df.loc[pref_name, "lon"]

    # 日ごとに繰り返し
    for date, value in confirmed_cases_daily_df.loc[pref_name].items():
        ax.scatter(lon, lat, int(date.split("-")[2]), c=value, cmap="viridis", s=value)

# カラーバーの表示
cbar = plt.colorbar(ax.collections[0])
cbar.set_label("Number of Infections")

# 軸ラベルの設定
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
ax.set_zlabel("Date")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/src/heat-map/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Kyoto'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[73], line 8
#       5 # 県ごとに繰り返し
# ...
